# %% [markdown]
# # Data Analysis with Python CognitiveClass DA0101EN

# %% [markdown]
# # Module 1- INTRODUCTION

# %%
QUESTION 1
What does CSV stand for ?
output- Comma Separated Values

QUESTION 2 
In the data set what represents an attribute or feature?
output- Column

QUESTION 3
What is another name for the variable that we want to predict?
output- Target 

QUESTION 4 
What is the command to display the first five rows of a dataframe df?
output- df.head() 

QUESTION 5
what command do you use to get the data type of each row of the dataframe df?
output- df.dtypes 

QUESTION 6 
How do you get a statistical summary of a dataframe df?
output- df.describe()

QUESTION 7
If you use the method describe() without changing any of the arguments you will 
get a statistical summary of all the columns of type object?

output- False

# %% [markdown]
# # Module 2- DATA WRANGLING

# %%
QUESTION 1 
Consider the dataframe "df" what is the result of the following operation df['symbolling'] = df['symbolling'] + 1?:
output- Every element in the column "symbolling" will increase by one

QUESTION 2 
Consider the dataframe "df", what does the command df.rename(columns={'a':'b'}) change about the dataframe "df"
output- nothing as you must set the parameter "inplace =True " 

QUESTION 3 
Consider the dataframe "df" , what is the result of the following operation df['price'] = df['price'].astype(int) 
output- convert or cast the column 'price' to an integer value

QUESTION 4 
Consider the column of the dataframe df['a']. The colunm has been standardized. What is the standard deviation of 
the values, i.e the result of applying the following operation df['a'].std() :
    output- 1
    
QUESTION 5 A) 
Consider the column of the dataframe df['Fuel'], with two values 'gas' and' diesel'. 
What will be the name of the new colunms pd.get_dummies(df['Fuel']) ?
output- Gas and diesel

QUESTION 5 B) 
What are the values of the new columns from part 5 a)
output- 1 and 0 1 and 0 - correct

# %% [markdown]
# # Module 3- Exploratory Data Analysis

# %%
QUESTION 1 
Consider the dataframe "df". Which method provides the summary statistics?
output- df.describe() 

QUESTION 2 
Consider the following dataframe:
    df_test = df['body-style', 'price']
The following operations is applied:
    df_grp = df_test.groupby(['body-style'], as_index=False).mean()
What are resulting values of df_grp[‘price’]:
output- The average price for each body style

QUESTION 3 
Correlation implies causation :
output- False 

QUESTION 4 
What is the minimum possible value of Pearson's Correlation :
output-  -1

QUESTION 5 
What is the Pearson correlation between variables X and Y, if X=Y:
output- 1

# %% [markdown]
# # Module 4 - Model Development

# %%
QUESTION 1 
Let X be a dataframe with 100 rows and 5 columns, let y be the target with 100 samples,
assuming all the relevant libraries and data have been imported, the following line of code has been executed:
LR = LinearRegression()
LR.fit(X, y)
yhat = LR.predict(X)
How many samples does yhat contain :
    output- 100
    
QUESTION 2 
What value of R^2 (coefficient of determination) indicates your model performs best ?
  output - 1

QUESTION 3 
What statement is true about Polynomial linear regression    
    output- Although the predictor variables of Polynomial linear regression are not linear 
    the relationship between the parameters or coefficients is linear. 

QUESTION 4 
The larger the mean square error, the better your model has performed
    output- False

QUESTION 5 
Assume all the libraries are imported, y is the target and X is the features or dependent variables, 
consider the following lines of code:

Input = [('scale', StandardScaler()), ('model', LinearRegression())]
pipe = Pipeline(Input)
pipe.fit(X,y)
ypipe = pipe.predict(X)
What have we just done in the above code?
    output- Standardize the data, then perform prediction using a linear regression model

# %% [markdown]
# # Module 5- Model Evaluation

# %%
QUESTION 1 
In the following plot, the vertical access shows the mean square error and
the horizontal axis represents the order of the polynomial. The red line represents
the training error the blue line is the test error. What is the best order of the 
polynomial given the possible choices in the horizontal axis?

Image Address- https://ibm.box.com/shared/static/tdzurm46b70txweeu0yzo2t2b9g2lbem.png
    
    output- 8

QUESTION 2
What is the correct use of the "train_test_split" function such that 40% of the data samples 
will be utilized for testing, the parameter "random_state" is set to zero, and the input variables
for the features and targets are_data, y_data respectively.
    output- train_test_split(x_data, y_data, test_size=0.4, random_state=0) 

QUESTION 3
What is the output of cross_val_score(lre, x_data, y_data, cv=2)?
    output- The average R^2 on the test data for each of the two folds
    
QUESTION 4 
What is the code to create a ridge regression object "RR" with an alpha term equal 10
    output- RR=Ridge(alpha=10) 
    
QUESTION 5
What dictionary value would we use to perform a grid search for the following values of
alpha: 1,10, 100. No other parameter values should be tested
    output-  [{'alpha': [1,10,100]}]

# %% [markdown]
# # Test

# %%
QUESTION 1 
What does the following command do:

df.dropna(subset=["price"], axis=0)
output - Drop the “not a number” from the column price Drop the “not a number” from the column price - correct

QUESTION 2 
How would you provide many of the summery statistics for all the columns in the dataframe "df":
output - df.describe(include = "all")

QUESTION 3 
How would you find the shape of the dataframe df
output - df.shape

QUESTION 4 
What task does the following command to df.to_csv("A.csv") perform
output - Save the dataframe df to a csv file called "A.csv"

QUESTION 5 
What task does the following line of code perform:

df['peak-rpm'].replace(np.nan, 5,inplace=True)
output - replace the not a number values with 5 in the column 'peak-rpm' replace the not a number values with 5 in the column 'peak-rpm' 

QUESTION 7 
How do you "one hot encode" the column 'fuel-type' in the dataframe df
output - pd.get_dummies(df["fuel-type"]) 

QUESTION 8 
What does the vertical axis in a scatter plot represent
output - dependent variable

QUESTION 9 
What does the horizontal axis in a scatter plot represent
output - independent variable

QUESTION 10 
If we have 10 columns and 100 samples how large is the output of df.corr()
output - 10 x 10

QUESTION 11 
what is the largest possible element resulting in the following operation "df.corr()"
output - 1

QUESTION 12 
if the Pearson Correlation of two variables is zero:
output - the two variables are not correlated

QUESTION 13 
if the p value of the Pearson Correlation is 1:
the variables are correlated/the variables are not correlated/none of the above
output - none of the above

QUESTION 14 
What does the following line of code do: lm = LinearRegression()
output -  create a linear regression object create a linear regression object

QUESTION 15 
If the predicted function is:
Yhat = a + b1 X1 + b2 X2 + b3 X3 + b4 X4
The method is:
output -  Multiple Linear Regression 

QUESTION 16 
What steps do the following lines of code perform:
Input=[('scale',StandardScaler()),('model',LinearRegression())]
pipe=Pipeline(Input)
pipe.fit(Z,y)
ypipe=pipe.predict(Z)
output -  Standardize the data, then perform a prediction using a linear regression model using the features Z and targets y

QUESTION 17 
What is the maximum value of R^2 that can be obtained
output - 1

QUESTION 18 
We create a polynomial feature as follows "PolynomialFeatures(degree=2)", what is the order of the polynomial
output - 2

QUESTION 19 
You have a linear model the average R^2 value on your training data is 0.5, you perform a 100th order polynomial transform on your data then use these values to train another model, your average R^2 is 0.99 which comment is correct: 100-th order polynomial will work better on unseen data/ You should always use the simplest model/ the results on your training data is not the best indicator of how your model performs, you should use your test data to get a beter idea
output -  the results on your training data is not the best indicator of how your model performs, you should use your test data to get a beter idea

QUESTION 20 
You train a ridge regression model, you get a R^2 of 1 on your training data and you get a R^2 of 0 on your validation data, what should you do:
output - Nothing your model performs flawlessly on your test data
